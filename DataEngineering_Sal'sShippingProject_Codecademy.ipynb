# %% [markdown]
# <a href="https://colab.research.google.com/github/silvia-j-escobar/DataEngineering_Codecademy/blob/main/DataEngineering_Sal'sShippingProject_Codecademy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Silvia

name = " "
question = "Will I win the lottery this year?"
answer = " "

import random

name = "Jeaneth"
random_number = random.randint(1, 9)
print()

if random_number == 1:
  answer = "Yes - definitely"
elif random_number == 2:
  answer = "It is decidedly so"
elif random_number == 3:
  answer = "Without a doubt"
elif random_number == 4:
  answer = "Reply hazy, try again"
elif random_number == 5:
  answer = "Ask again later"
elif random_number == 6:
  answer = "Better not tell you now"
elif random_number == 7:
  answer = "My sources say no"
elif random_number == 8:
  answer = "Outlook not so good"
elif random_number == 9:
  answer = "Very doubtful"
answers = [
"Yes - definitely", "It is decidedly so", "Without a doubt",
    "Reply hazy, try again", "Ask again later", "Better not tell you now",
    "My sources say no", "Outlook not so good", "Very doubtful"
]
answer = answers[random_number - 1]  # simple mapping

#else:
 # answer = "Error"
print(name + " asks: " + question)
# Task 10
print ("Magic 8-Ball's answer: " + answer
)
# Out:
# Jeaneth asks: Will I win the lottery this year?
# Magic 8-Ball's answer: Better not tell you now
